# %%
import pandas as pd
import csv
import os
df = pd.read_csv('csv/df.csv')
book = pd.read_csv('csv/book.csv')
df["num_pages"] = book["num_pages"]
df
# Out:
#              isbn                                      title  \
# 0   9780552149518                          The Da Vinci Code
# 1   9780747532743   Harry Potter and the Philosopher's Stone
# 2   9780747538486    Harry Potter and the Chamber of Secrets
# 3   9780552150736                          Angels and Demons
# 4   9780747551003  Harry Potter and the Order of the Phoenix
# ..            ...                                        ...
# 95  9780439993586   The Amber Spyglass:His Dark Materials S.
# 96  9780552771108                     Can You Keep a Secret?
# 97  9780552997034                                 Down Under
# 98  9780099506928                           Spot of Bother,A
# 99  9781846053443                                 Dear Fatty
#
#               author            publisher  price                        genre  \
# 0         Brown, Dan       Transworld Grp      8  Crime, Thriller & Adventure
# ...
